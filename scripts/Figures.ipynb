]

# Updated Model_Type list to match the length of y_values and y_errors
model_types = ['Lre4', 'Lre5', 'Lre6']

data = pd.DataFrame({
    'Model': models * 3,
    'Accuracy': [val for sublist in y_values for val in sublist],
    'Model_Type': [model for model_type in model_types for model in [model_type] * num_labels],
    'Errors': [val for sublist in y_errors for val in sublist],
})

plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Model', y='Accuracy', data=data, hue='Model_Type', palette='Set2')

for i, model_type in enumerate(model_types):
    x_coords = [p.get_x() + p.get_width() / 2 for p in ax.containers[i]]
    y_coords = y_values[i]
    y_errs = y_errors[i]
    ax.errorbar(x=x_coords, y=y_coords, yerr=y_errs, fmt='none', c='black', capsize=5)

y_tick_positions = np.arange(0, 1.1, 0.1)
y_tick_labels = [f'{tick:.1f}' for tick in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

ax.tick_params(axis='x', labelsize=13)
ax.tick_params(axis='y', labelsize=13)

# Set y-axis limits to [0, 1]
ax.set_ylim(0.5, 1)

# Add labels and title
ax.set_xlabel('Model Type', fontsize=13)
ax.set_ylabel('Accuracy', fontsize=13)
# ax.set_title('Classification Accuracy of LazDEF Models (Low-N Condition)', pad=20, fontsize=14)

# Create a custom legend with colored rectangles
# legend_labels = ['Vanilla-ESM', 'Peptide-ESM', 'LazBF-ESM', 'LazDEF-ESM']
# legend_colors = [sns.color_palette("Set2")[0], sns.color_palette("Set2")[1], sns.color_palette("Set2")[2]]
# legend_elements = [Patch(color=color, label=label) for color, label in zip(legend_colors, legend_labels)]
# ax.legend(handles=legend_elements, title='PLM', loc='center left', bbox_to_anchor=(1, 0.5))
# plt.text(-0.1, 1.15, 'a', fontsize=20, transform=ax.transAxes)
ax.get_legend().remove()

# Show the plot
plt.savefig('Different_learningRates.png', dpi=600, bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ---

# %%
#@title Comparing different number of training epochs for LazDEF-ESM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch

models = ['LR', 'RF', 'AB', 'SVC', 'MLP']
num_labels = len(models)
y_values = [[0.9138, 0.8864000000000001, 0.8936, 0.915, 0.9172], [0.9136, 0.8835999999999998, 0.8852, 0.9094, 0.9176], [0.9141999999999999, 0.883, 0.8837999999999999, 0.9108, 0.9176], [0.9161999999999999, 0.8832000000000001, 0.8907999999999999, 0.9106, 0.9183999999999999], [0.9171999999999999, 0.875, 0.8922000000000001, 0.9076000000000001, 0.9172]]

y_errors = [[0.0015620499351813733, 0.0021587033144923047, 0.005546169849544808, 0.0029154759474226567, 0.0020099751242241798], [0.001860107523773834, 0.002993325909419171, 0.0032771939216348052, 0.0027676705006196268, 0.0022494443758403807], [0.002973213749463667, 0.0020248456731316467, 0.003512833614050037, 0.0037067505985701565, 0.0009273618495495629], [0.003120897306865436, 0.0032155870381627236, 0.0034117444218463963, 0.002063976744055047, 0.0024207436873820588], [0.0012806248474865707, 0.002774887385102324, 0.0028530685235374233, 0.0027495454169735208, 0.0007348469228349405]]

# Updated Model_Type list to match the length of y_values and y_errors
model_types = ['Vanilla-ESM', 'Peptide-ESM', 'LazBF-ESM', 'LazDEF-ESM', 'LazBCDEF-ESM']

data = pd.DataFrame({
    'Model': models * 5,
    'Accuracy': [val for sublist in y_values for val in sublist],
    'Model_Type': [model for model_type in model_types for model in [model_type] * num_labels],
    'Errors': [val for sublist in y_errors for val in sublist],
})

plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Model', y='Accuracy', data=data, hue='Model_Type', palette='Set2')

for i, model_type in enumerate(model_types):
    x_coords = [p.get_x() + p.get_width() / 2 for p in ax.containers[i]]
    y_coords = y_values[i]
    y_errs = y_errors[i]
    ax.errorbar(x=x_coords, y=y_coords, yerr=y_errs, fmt='none', c='black', capsize=5)

y_tick_positions = np.arange(0, 1.1, 0.1)
y_tick_labels = [f'{tick:.1f}' for tick in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

# Set y-axis limits to [0, 1]
ax.set_ylim(0.5, 1)

# Add labels and title
ax.set_xlabel('Model Type', fontsize=13)
ax.set_ylabel('Accuracy', fontsize=13)
# ax.set_title('Classification Accuracy of LazDEF Models (High-N Condition)', pad=20, fontsize=14)
ax.tick_params(axis='x', labelsize=13)
ax.tick_params(axis='y', labelsize=13)

# Create a custom legend with colored rectangles
# legend_labels = ['Vanilla-ESM', 'Peptide-ESM', 'LazBF-ESM', 'LazDEF-ESM']
# legend_colors = [sns.color_palette("Set2")[0], sns.color_palette("Set2")[1], sns.color_palette("Set2")[2]]
# legend_elements = [Patch(color=color, label=label) for color, label in zip(legend_colors, legend_labels)]
# ax.legend(handles=legend_elements, title='PLM', loc='center left', bbox_to_anchor=(1, 0.5))
# plt.text(-0.1, 1.15, 'a', fontsize=20, transform=ax.transAxes)
ax.get_legend().remove()

# Show the plot
plt.savefig('LazDEFExtended', dpi=400, bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
